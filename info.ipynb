# %%
import airflow
# Out:
# [2018-07-21 14:24:02,789] {__init__.py:57} INFO - Using executor SequentialExecutor

# %%
from airflow import DAG

# %%
import tushare as ts

# %%
ts.get_day_all()
# Out:
#         code   name  p_change  price  change   open   high    low  preprice  \
# 0     601869    N长飞     43.99  38.46   11.75  32.05  38.46  32.05     26.71
# 1     000955   欣龙控股     10.14   4.02    0.37   4.02   4.02   4.02      3.65
# 2     002195   二三四五     10.10   4.47    0.41   4.12   4.47   4.09      4.06
# 3     002580   圣阳股份     10.09   6.22    0.57   5.65   6.22   5.63      5.65
# 4     002608   江苏国信     10.07   7.87    0.72   7.10   7.87   7.10      7.15
# 5     601838   成都银行     10.06   8.86    0.81   8.01   8.86   7.93      8.05
# 6     600734   实达集团     10.06   7.33    0.67   6.90   7.33   6.86      6.66
# 7     603021   山东华鹏     10.06   7.77    0.71   7.12   7.77   7.08      7.06
# 8     002807   江阴银行     10.06   5.91    0.54   5.36   5.91   5.30      5.37
# 9     300299   富春股份     10.04   5.15    0.47   4.55   5.15   4.53      4.68
# 10    002857   三晖电气     10.04  13.04    1.19  12.80  13.04  12.58     11.85
# ...

# %%
ts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5146c4e22799> in <module>()
# ----> 1 ts
#
# NameError: name 'ts' is not defined
