# %%
import pandas as pd

# %%
result = pd.read_csv('C:\stockdata\caiwu\income.csv')

# %%
from datetime import datetime

# %%
result['pubDate'] = result['pubDate'].str.replace('-', '')
print(result['pubDate'])
# Out:
# 0         20050426
# 1         20050819
# 2         20051029
# 3         20060401
# 4         20060426
# 5         20060818
# 6         20061026
# 7         20070322
# 8         20070426
# 9         20070816
# 10        20071023
# 11        20080320
# 12        20080424
# 13        20080821
# 14        20081024
# 15        20090320
# 16        20090424
# 17        20090821
# 18        20091029
# 19        20100312
# 20        20100429
# 21        20100825
# 22        20101028
# 23        20110225
# 24        20110427
# 25        20110818
# 26        20111026
# 27        20120309
# 28        20120426
# 29        20120816
#             ...
# 107629    20150828
# 107630    20151030
# 107631    20160426
# 107632    20160430
# 107633    20160826
# 107634    20161029
# 107635    20170418
# 107636    20170426
# 107637    20170828
# 107638    20171028
# 107639    20150302
# 107640    20150428
# 107641    20150821
# 107642    20151029
# 107643    20160330
# 107644    20160420
# ...

# %%
result.rename(columns={"statDate.1":"statDate_1"}, inplace = True)

# %%
result.dtypes
# Out:
# id                                       int64
# code                                    object
# statDate                                object
# pubDate                                 object
# statDate_1                              object
# total_operating_revenue                float64
# operating_revenue                      float64
# interest_income                        float64
# premiums_earned                        float64
# commission_income                      float64
# total_operating_cost                   float64
# operating_cost                         float64
# interest_expense                       float64
# commission_expense                     float64
# refunded_premiums                      float64
# net_pay_insurance_claims               float64
# withdraw_insurance_contract_reserve    float64
# policy_dividend_payout                 float64
# reinsurance_cost                       float64
# operating_tax_surcharges               float64
# ...

# %%
import pymongo
import json

# %%
del result['id']

# %%
conn = pymongo.MongoClient('127.0.0.1', 27017)

conn.stockdata.income.insert(json.loads(result.to_json(orient='records')))
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [ObjectId('5ab4692f2e56542ac0d7fae2'),
#  ObjectId('5ab4692f2e56542ac0d7fae3'),
#  ObjectId('5ab4692f2e56542ac0d7fae4'),
#  ObjectId('5ab4692f2e56542ac0d7fae5'),
#  ObjectId('5ab4692f2e56542ac0d7fae6'),
#  ObjectId('5ab4692f2e56542ac0d7fae7'),
#  ObjectId('5ab4692f2e56542ac0d7fae8'),
#  ObjectId('5ab4692f2e56542ac0d7fae9'),
#  ObjectId('5ab4692f2e56542ac0d7faea'),
#  ObjectId('5ab4692f2e56542ac0d7faeb'),
#  ObjectId('5ab4692f2e56542ac0d7faec'),
#  ObjectId('5ab4692f2e56542ac0d7faed'),
#  ObjectId('5ab4692f2e56542ac0d7faee'),
#  ObjectId('5ab4692f2e56542ac0d7faef'),
#  ObjectId('5ab4692f2e56542ac0d7faf0'),
#  ObjectId('5ab4692f2e56542ac0d7faf1'),
#  ObjectId('5ab4692f2e56542ac0d7faf2'),
#  ObjectId('5ab4692f2e56542ac0d7faf3'),
# ...

# %%
result = pd.read_csv('C:\stockdata\caiwu\cash_flow.csv')

# %%
result.dtypes
# Out:
# id                                               int64
# code                                            object
# statDate                                        object
# pubDate                                         object
# statDate.1                                      object
# goods_sale_and_service_render_cash             float64
# net_deposit_increase                           float64
# net_borrowing_from_central_bank                float64
# net_borrowing_from_finance_co                  float64
# net_original_insurance_cash                    float64
# net_cash_received_from_reinsurance_business    float64
# net_insurer_deposit_investment                 float64
# net_deal_trading_assets                        float64
# interest_and_commission_cashin                 float64
# net_increase_in_placements                     float64
# net_buyback                                    float64
# tax_levy_refund                                float64
# ...

# %%
result.rename(columns={"statDate.1":"statDate_1"}, inplace = True)

# %%
result.dtypes
# Out:
# id                                               int64
# code                                            object
# statDate                                        object
# pubDate                                         object
# statDate_1                                      object
# goods_sale_and_service_render_cash             float64
# net_deposit_increase                           float64
# net_borrowing_from_central_bank                float64
# net_borrowing_from_finance_co                  float64
# net_original_insurance_cash                    float64
# net_cash_received_from_reinsurance_business    float64
# net_insurer_deposit_investment                 float64
# net_deal_trading_assets                        float64
# interest_and_commission_cashin                 float64
# net_increase_in_placements                     float64
# net_buyback                                    float64
# tax_levy_refund                                float64
# ...

# %%
conn = pymongo.MongoClient('127.0.0.1', 27017)

conn.stockdata.cash_flow.insert(json.loads(result.to_json(orient='records')))
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [ObjectId('5ab46bb32e56542ac0d99f6e'),
#  ObjectId('5ab46bb32e56542ac0d99f6f'),
#  ObjectId('5ab46bb32e56542ac0d99f70'),
#  ObjectId('5ab46bb32e56542ac0d99f71'),
#  ObjectId('5ab46bb32e56542ac0d99f72'),
#  ObjectId('5ab46bb32e56542ac0d99f73'),
#  ObjectId('5ab46bb32e56542ac0d99f74'),
#  ObjectId('5ab46bb32e56542ac0d99f75'),
#  ObjectId('5ab46bb32e56542ac0d99f76'),
#  ObjectId('5ab46bb32e56542ac0d99f77'),
#  ObjectId('5ab46bb32e56542ac0d99f78'),
#  ObjectId('5ab46bb32e56542ac0d99f79'),
#  ObjectId('5ab46bb32e56542ac0d99f7a'),
#  ObjectId('5ab46bb32e56542ac0d99f7b'),
#  ObjectId('5ab46bb32e56542ac0d99f7c'),
#  ObjectId('5ab46bb32e56542ac0d99f7d'),
#  ObjectId('5ab46bb32e56542ac0d99f7e'),
#  ObjectId('5ab46bb32e56542ac0d99f7f'),
# ...

# %%
result = pd.read_csv('C:\\stockdata\\caiwu\\balance.csv')

# %%
result.dtypes
# Out:
# id                                               int64
# code                                            object
# statDate                                        object
# pubDate                                         object
# statDate.1                                      object
# cash_equivalents                               float64
# settlement_provi                               float64
# lend_capital                                   float64
# trading_assets                                 float64
# bill_receivable                                float64
# account_receivable                             float64
# advance_payment                                float64
# insurance_receivables                          float64
# reinsurance_receivables                        float64
# reinsurance_contract_reserves_receivable       float64
# interest_receivable                            float64
# dividend_receivable                            float64
# ...

# %%
result.rename(columns={"statDate.1":"statDate_1"}, inplace = True)

# %%
conn = pymongo.MongoClient('127.0.0.1', 27017)
del result['id']

# %%
df = result.iloc[:80000]

conn.stockdata.balance.insert(json.loads(df.to_json(orient='records')))
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [ObjectId('5ab470fc2e56542a249e858d'),
#  ObjectId('5ab470fc2e56542a249e858e'),
#  ObjectId('5ab470fc2e56542a249e858f'),
#  ObjectId('5ab470fc2e56542a249e8590'),
#  ObjectId('5ab470fc2e56542a249e8591'),
#  ObjectId('5ab470fc2e56542a249e8592'),
#  ObjectId('5ab470fc2e56542a249e8593'),
#  ObjectId('5ab470fc2e56542a249e8594'),
#  ObjectId('5ab470fc2e56542a249e8595'),
#  ObjectId('5ab470fc2e56542a249e8596'),
#  ObjectId('5ab470fc2e56542a249e8597'),
#  ObjectId('5ab470fc2e56542a249e8598'),
#  ObjectId('5ab470fc2e56542a249e8599'),
#  ObjectId('5ab470fc2e56542a249e859a'),
#  ObjectId('5ab470fc2e56542a249e859b'),
#  ObjectId('5ab470fc2e56542a249e859c'),
#  ObjectId('5ab470fc2e56542a249e859d'),
#  ObjectId('5ab470fc2e56542a249e859e'),
# ...

# %%
df = result.iloc[80000:]

conn.stockdata.balance.insert(json.loads(df.to_json(orient='records')))
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [ObjectId('5ab4710b2e56542a249fbe0d'),
#  ObjectId('5ab4710b2e56542a249fbe0e'),
#  ObjectId('5ab4710b2e56542a249fbe0f'),
#  ObjectId('5ab4710b2e56542a249fbe10'),
#  ObjectId('5ab4710b2e56542a249fbe11'),
#  ObjectId('5ab4710b2e56542a249fbe12'),
#  ObjectId('5ab4710b2e56542a249fbe13'),
#  ObjectId('5ab4710b2e56542a249fbe14'),
#  ObjectId('5ab4710b2e56542a249fbe15'),
#  ObjectId('5ab4710b2e56542a249fbe16'),
#  ObjectId('5ab4710b2e56542a249fbe17'),
#  ObjectId('5ab4710b2e56542a249fbe18'),
#  ObjectId('5ab4710b2e56542a249fbe19'),
#  ObjectId('5ab4710b2e56542a249fbe1a'),
#  ObjectId('5ab4710b2e56542a249fbe1b'),
#  ObjectId('5ab4710b2e56542a249fbe1c'),
#  ObjectId('5ab4710b2e56542a249fbe1d'),
#  ObjectId('5ab4710b2e56542a249fbe1e'),
# ...

# %%
result.iloc[:,0].size
# Out:
# 107689
