# %%
import pandas as pd

path = "C:\\stockdata\\economic\\"

# %%
lilvdf = pd.read_excel(path + "lilv.xls", sheetname="lilv")

# %%
import matplotlib .pyplot as plt

# %%
plt.plot(lilvdf['date'],lilvdf['lilv'])
plt.show()

# %%
meigudf = pd.read_excel(path + "meigu.xls", sheetname="meigu")

# %%
meigudf.dtypes
# Out:
# date      datetime64[ns]
# dj               float64
# sp               float64
# nasdaq           float64
# dtype: object

# %%
plt.plot(meigudf['date'], meigudf['dj'], label='dj')
plt.plot(meigudf['date'], meigudf['sp'], label='sp')
plt.plot(meigudf['date'], meigudf['nasdaq'], label='nasdaq')
plt.show()

# %%
fig, ax1 = plt.subplots()
plt.plot(meigudf['date'], meigudf['dj'], label='dj')
ax2 = ax1.twinx()
plt.plot(lilvdf['date'],lilvdf['lilv'], label='lilv')
plt.show()

# %%
fig, ax1 = plt.subplots()
plt.plot(meigudf['date'], meigudf['sp'], label='dj')
ax2 = ax1.twinx()
plt.plot(lilvdf['date'],lilvdf['lilv'], label='lilv')
plt.show()

# %%
fig, ax1 = plt.subplots()
plt.plot(meigudf['date'], meigudf['nasdaq'], label='dj')
ax2 = ax1.twinx()
plt.plot(lilvdf['date'],lilvdf['lilv'], label='lilv')
plt.show()

# %%
gloddf = pd.read_excel(path + "glod.xls", sheetname="glod")

# %%
gloddf.dtypes
# Out:
# date     object
# glod    float64
# dtype: object

# %%
gloddf['date'] = pd.to_datetime(gloddf['date'])

# %%
fig, ax1 = plt.subplots()
plt.plot(gloddf['date'], gloddf['glod'], label='glod', color='red')
ax2 = ax1.twinx()
plt.plot(lilvdf['date'],lilvdf['lilv'], label='lilv')
plt.show()

# %%
fig, ax1 = plt.subplots()
plt.plot(meigudf['date'], meigudf['sp'], label='dj')
ax2 = ax1.twinx()
plt.plot(gloddf['date'], gloddf['glod'], label='glod', color='red')
plt.show()

# %%
szzsdf = pd.read_excel(path + "shangzhengzhishu.xls", sheetname="szzs")

# %%
szzsdf.dtypes
# Out:
# index                      int64
# date              datetime64[ns]
# open                     float64
# high                     float64
# low                      float64
# close                    float64
# zhangdie                 float64
# zhangdiefu               float64
# chengjiaoliang             int64
# chengjiaoe                 int64
# dtype: object

# %%
fig, ax1 = plt.subplots()
plt.plot(meigudf['date'], meigudf['sp'], label='dj')
ax2 = ax1.twinx()
plt.plot(szzsdf['date'], szzsdf['close'], label='szzs', color='red')
plt.show()

# %%
fig, ax1 = plt.subplots()
plt.plot(szzsdf['date'], szzsdf['close'], label='szzs', color='red')
ax2 = ax1.twinx()
plt.plot(lilvdf['date'],lilvdf['lilv'], label='lilv')
plt.show()

# %%
fig, ax1 = plt.subplots()
plt.plot(szzsdf['date'], szzsdf['close'], label='szzs', color='red')
ax2 = ax1.twinx()
plt.plot(gloddf['date'], gloddf['glod'], label='glod')
plt.show()

# %%
clilvdf = pd.read_excel(path + "clilv.xls", sheetname="lilv")

# %%
clilvdf['date'] = pd.to_datetime(clilvdf['date'])

# %%
fig, ax1 = plt.subplots()
plt.plot(szzsdf['date'], szzsdf['close'], label='szzs', color='red')
ax2 = ax1.twinx()
plt.plot(clilvdf['date'], clilvdf['lilv'], label='clilv')
plt.show()

# %%
clilvdf.dtypes
# Out:
# date    datetime64[ns]
# lilv           float64
# dtype: object

# %%
szzsdf = szzsdf.set_index('date')

# %%
clilvdf = clilvdf.set_index('date')

# %%
clilvdf = szzsdf.join(clilvdf, how='outer', sort=True)

# %%
del clilvdf['chengjiaoe']

# %%
clilvdf.columns
# Out:
# Index(['lilv'], dtype='object')

# %%
clivdf = clilvdf.sort_index(ascending=False)

# %%
clivdf = clivdf.fillna(method='ffill')

# %%
clivdf = clivdf.fillna(1.5)

# %%
clivdf.to_csv(path + 'clilv2.csv')

# %%
clivdf.plot()

# %%
plt.show()
