# %%
import tushare as ts

# %%
ts.get_report_data(2003,3)
# Out:
# [Getting data:]####################
#         code   name  eps  eps_yoy  bvps    roe  epcf  net_profits  \
# 0     600438   通威股份  NaN      NaN  2.31  13.65  0.62      3307.05
# 1     600493   凤竹纺织  NaN      NaN  1.67  14.90  0.50      2550.67
# 2     600340   华夏幸福  NaN      NaN  2.01  15.08  0.58      1688.47
# 3     600476   湘邮科技  NaN      NaN  1.83  11.43  0.01      1347.94
# 4     600545   卓郎智能  NaN      NaN   NaN    NaN   NaN      2439.13
# 5     600100   同方股份  NaN      NaN  5.01    NaN   NaN     10711.89
# 6     600158   中体产业  NaN      NaN  3.10    NaN   NaN       390.77
# 7     600658    电子城  NaN      NaN  1.64    NaN   NaN     -2716.07
# 8     000539   粤电力A  NaN      NaN  2.86    NaN   NaN     98446.27
# 9     000558   莱茵体育  NaN      NaN  0.93    NaN   NaN     -1614.57
# 10    600744   华银电力  NaN      NaN  4.05    NaN   NaN       512.95
# 11    000601   韶能股份  NaN      NaN  5.02    NaN   NaN     11206.53
# 12    600779    水井坊  NaN      NaN  2.10    NaN   NaN    -15778.47
# ...

# %%
df = ts.get_stock_basics()

# %%
df
# Out:
#          name industry area       pe  outstanding  totals  totalAssets  \
# code
# 000890  法 尔 胜      钢加工   江苏   107.62         3.80    3.80   1113305.25
# 002472   双环传动     机械基件   浙江    28.50         5.44    6.84    574330.94
# 002666   德联集团     化工原料   广东    44.57         4.44    7.54    337337.06
# 000151   中成股份     商贸代理   北京    41.11         2.67    2.96    230761.38
# 002651   利君股份     专用机械   四川    75.73         3.78   10.03    244765.77
# 600213   亚星客车     汽车整车   江苏    67.11         2.20    2.20    485918.00
# 600804    鹏博士     电信运营   四川    26.86        14.32   14.32   2346922.50
# 002069    獐子岛       渔业   辽宁    34.67         6.87    7.11    462153.44
# 000530   大冷股份     机械基件   辽宁    27.65         5.93    8.56    554875.88
# 603778   乾景园林     建筑施工   北京    78.88         2.26    5.00    163372.88
# 000810   创维数字     家用电器   四川   124.47         9.90   10.71    721120.56
# 002877   智能自控     电器仪表   江苏    79.20         0.31    1.22     82386.47
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3502 entries, 000890 to 000950
# Data columns (total 22 columns):
# name                3502 non-null object
# industry            3502 non-null object
# area                3502 non-null object
# pe                  3502 non-null float64
# outstanding         3502 non-null float64
# totals              3502 non-null float64
# totalAssets         3502 non-null float64
# liquidAssets        3502 non-null float64
# fixedAssets         3502 non-null float64
# reserved            3502 non-null float64
# reservedPerShare    3502 non-null float64
# esp                 3502 non-null float64
# bvps                3502 non-null float64
# pb                  3502 non-null float64
# timeToMarket        3502 non-null int64
# undp                3502 non-null float64
# perundp             3502 non-null float64
# rev                 3502 non-null float64
# profit              3502 non-null float64
# gpr                 3502 non-null float64
# ...

# %%
df['timeToMarket']
# Out:
# code
# 000890    19990119
# 002472    20100910
# 002666    20120327
# 000151    20000906
# 002651    20120106
# 600213    19990831
# 600804    19940103
# 002069    20060928
# 000530    19931208
# 603778    20151231
# 000810    19980602
# 002877    20170605
# 000948    19991014
# 300300    20120319
# 002927    20180223
# 603506    20180201
# 300534    20160913
# 300490    20151231
# 300104    20100812
# 300099    20100806
# 000957    20000113
# 300678    20170728
# 603712    20180226
# 300647    20170503
# 002790    20160308
# 601500    20160919
# 002189    20071203
# 600523    20011227
# 002606    20110805
# 600962    20040622
#             ...
# 603083    20171110
# 300644    20180206
# 002863    20170418
# 300277    20111123
# 300344    20120801
# 002903    20171013
# 002928    20180302
# 002907    20171020
# 300413    20150121
# 002916    20171213
# 300462    20150527
# 603058    20161223
# 002883    20170620
# 600238    20000120
# 600207    19990714
# 002208    20080128
# ...

# %%
df.set_index('timeToMarket')
# Out:
#                name industry area       pe  outstanding  totals  totalAssets  \
# timeToMarket
# 19990119      法 尔 胜      钢加工   江苏   107.62         3.80    3.80   1113305.25
# 20100910       双环传动     机械基件   浙江    28.50         5.44    6.84    574330.94
# 20120327       德联集团     化工原料   广东    44.57         4.44    7.54    337337.06
# 20000906       中成股份     商贸代理   北京    41.11         2.67    2.96    230761.38
# 20120106       利君股份     专用机械   四川    75.73         3.78   10.03    244765.77
# 19990831       亚星客车     汽车整车   江苏    67.11         2.20    2.20    485918.00
# 19940103        鹏博士     电信运营   四川    26.86        14.32   14.32   2346922.50
# 20060928        獐子岛       渔业   辽宁    34.67         6.87    7.11    462153.44
# 19931208       大冷股份     机械基件   辽宁    27.65         5.93    8.56    554875.88
# 20151231       乾景园林     建筑施工   北京    78.88         2.26    5.00    163372.88
# 19980602       创维数字     家用电器   四川   124.47         9.90   10.71    721120.56
# ...

# %%
df[20170101:20180101]
# Out:
# Empty DataFrame
# Columns: [name, industry, area, pe, outstanding, totals, totalAssets, liquidAssets, fixedAssets, reserved, reservedPerShare, esp, bvps, pb, timeToMarket, undp, perundp, rev, profit, gpr, npr, holders]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.reindex()
# Out:
#          name industry area       pe  outstanding  totals  totalAssets  \
# code
# 000890  法 尔 胜      钢加工   江苏   107.62         3.80    3.80   1113305.25
# 002472   双环传动     机械基件   浙江    28.50         5.44    6.84    574330.94
# 002666   德联集团     化工原料   广东    44.57         4.44    7.54    337337.06
# 000151   中成股份     商贸代理   北京    41.11         2.67    2.96    230761.38
# 002651   利君股份     专用机械   四川    75.73         3.78   10.03    244765.77
# 600213   亚星客车     汽车整车   江苏    67.11         2.20    2.20    485918.00
# 600804    鹏博士     电信运营   四川    26.86        14.32   14.32   2346922.50
# 002069    獐子岛       渔业   辽宁    34.67         6.87    7.11    462153.44
# 000530   大冷股份     机械基件   辽宁    27.65         5.93    8.56    554875.88
# 603778   乾景园林     建筑施工   北京    78.88         2.26    5.00    163372.88
# 000810   创维数字     家用电器   四川   124.47         9.90   10.71    721120.56
# 002877   智能自控     电器仪表   江苏    79.20         0.31    1.22     82386.47
# ...

# %%
df[(df['timeToMarket'] > 20170101) & (df['timeToMarket'] < 20180101)]
# Out:
#         name industry area       pe  outstanding  totals  totalAssets  \
# code
# 002877  智能自控     电器仪表   江苏    79.20         0.31    1.22     82386.47
# 300678  中科信息     软件服务   四川   390.83         0.25    1.00     66166.78
# 300647   超频三      元器件   深圳    71.80         0.30    1.23     83115.93
# 601366  利群股份       百货   山东    27.80         1.76    8.61    803135.00
# 300631  久吾高科     环境保护   江苏    78.88         0.26    1.03     74781.38
# 002892   科力尔     电气设备   湖南    46.82         0.18    0.84     67042.00
# 300620  光库科技      元器件   广东    59.10         0.22    0.88     52511.70
# 300677  英科医疗     医疗保健   山东    52.20         0.24    0.98    165823.69
# 603557  起步股份       服饰   浙江    43.11         0.47    4.70    171040.88
# 601858  中国科传      出版业   北京    38.49         1.31    7.91    410007.59
# 002850   科达利     机械基件   深圳    35.96         0.62    1.40    311385.94
# 603637  镇海股份     建筑施工   浙江    60.13         0.33    1.33     86330.46
# ...

# %%
df.sort_values(by='timeToMarket')
# Out:
#          name industry area        pe  outstanding  totals   totalAssets  \
# code
# 002930   宏川智慧     仓储物流   广东      0.00         0.00    0.00  1.872708e+05
# 300634   彩讯股份     软件服务   深圳      0.00         0.00    0.00  1.006216e+05
# 600929   湖南盐业       食品   湖南      0.00         0.00    0.00  3.104916e+05
# 000005   世纪星源     房产服务   深圳      0.00         9.51   10.59  2.792868e+05
# 600652   游久游戏      互联网   上海    115.42         8.33    8.33  2.440706e+05
# 600602   云赛智联     软件服务   上海     46.92         8.80   13.68  5.278168e+05
# 600601   方正科技     电脑设备   上海      0.00        21.95   21.95  1.106596e+06
# 600651   飞乐音响     电器仪表   上海     13.58         9.85    9.91  1.561412e+06
# 600653   申华控股     汽车服务   上海      0.00        17.46   19.46  9.553699e+05
# 600654  *ST中安     软件服务   上海      0.00         7.55   12.83  9.920041e+05
# 000004   国农科技     生物制药   深圳      0.00         0.83    0.84  2.412107e+04
# 000002   万 科Ａ     全国地产   深圳     24.25        97.09  110.39  1.018382e+08
# ...

# %%
df20173 = ts.get_report_data(2017,3)
# Out:
# [Getting data:]##########################################################

# %%
df = ts.get_stock_basics("2018-01-04")

# %%
df
# Out:
#          name industry area       pe  outstanding  totals  totalAssets  \
# code
# 000836   鑫茂科技     通信设备   天津    66.63        11.83   12.08    273369.34
# 600191   华资实业       食品   内蒙    89.71         4.85    4.85    261745.25
# Out:
#          name industry area       pe  outstanding  totals  totalAssets  \
# code
# 600996    N贵广     影视音像   贵州    23.99         2.10   10.43    465794.00
# 603058   永吉股份     广告包装   贵州    35.44         0.42    4.22     63957.38
# 000812   陕西金叶     广告包装   陕西   191.34         4.46    4.47    204223.73
# 002826   易明医药     化学制药   西藏    99.65         0.47    1.90     41692.43
# 603878   武进不锈      钢加工   江苏    58.53         0.51    2.02    172152.67
# 603389   亚振家居     家居用品   江苏    85.92         0.55    2.19     60124.23
# 603577    汇金通      钢加工   山东    36.71         0.29    1.17    101383.60
# 300080   易成新能      半导体   河南  1121.48         5.02    5.03    596989.13
# 300579   数字认证     软件服务   北京    70.23         0.20    0.80     40868.62
# 300571   平治信息      互联网   浙江    34.51         0.10    0.40     21942.17
# 300565   科信技术     通信设备   深圳    89.52         0.40    1.60     87290.11
# 002346   柘中股份     电气设备   上海   768.69         0.80    4.42    226300.95
# ...

# %%
ts.get_stock_basics("2015-12-21")

# %%
ts.get_day_all()
# Out:
#         code   name  p_change   price  change    open    high     low  \
# 0     000882   华联股份     10.09    3.49    0.32    3.29    3.49    3.24
# 1     600635   大众公用     10.06    5.14    0.47    4.79    5.14    4.75
# 2     002702   海欣食品     10.06    5.58    0.51    5.29    5.58    5.18
# 3     000909   数源科技     10.04   10.96    1.00    9.94   10.96    9.91
# 4     600895   张江高科     10.03   14.59    1.33   13.38   14.59   13.36
# 5     600213   亚星客车     10.03   11.41    1.04   10.50   11.41   10.31
# 6     603778   乾景园林     10.03    7.79    0.71    6.91    7.79    6.84
# 7     600865   百大集团     10.03    8.12    0.74    7.43    8.12    7.39
# 8     300390   天华超净     10.02   10.76    0.98   10.30   10.76   10.30
# 9     002208   合肥城建     10.02   16.47    1.50   16.36   16.47   15.80
# 10    300680   隆盛科技     10.02   29.21    2.66   26.56   29.21   26.56
# 11    300020   银江股份     10.02   12.19    1.11   11.23   12.19   11.23
# ...

# %%
ts.get_today_all()
# Out:
# [Getting data:]#############################
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-27-adeafa9c676b> in <module>()
# ----> 1 ts.get_today_all()
#
# C:\Program Files (x86)\Anaconda3\lib\site-packages\tushare\stock\trading.py in get_today_all()
#     315     if df is not None:
#     316         for i in range(2, ct.PAGE_NUM[1]):
# --> 317             newdf = _parsing_dayprice_json('hs_a', i)
#     318             df = df.append(newdf, ignore_index=True)
#     319     df = df.append(_parsing_dayprice_json('shfxjs', 1),
#
# C:\Program Files (x86)\Anaconda3\lib\site-packages\tushare\stock\trading.py in _parsing_dayprice_json(types, page)
#     114     request = Request(ct.SINA_DAY_PRICE_URL%(ct.P_TYPE['http'], ct.DOMAINS['vsf'],
#     115                                  ct.PAGES['jv'], types, page))
# --> 116     text = urlopen(request, timeout=10).read()
# ...
