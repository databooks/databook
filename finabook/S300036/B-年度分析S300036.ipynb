# %%
import tushare as ts
import pandas  as pd
import numpy  as np
import matplotlib.pyplot as plt
from   pylab  import  *

# %% [markdown]
# # 年度分析
#
# 获取月线数据，排序。

# %%
df = ts.get_hist_data('300036',ktype='M')

# %%
df.head(20)
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2019-02-20  13.21  16.71  16.20  13.10  1194922.25          3.37     25.90
# 2019-01-31  18.15  18.28  13.01  13.01  2147358.00         -5.32    -29.02
# 2018-12-28  19.00  19.38  18.33  17.31        0.00         -0.07     -0.38
# 2018-11-30  19.00  20.94  18.40  17.21        0.00         -0.27     -1.45
# 2018-10-31  21.80  22.18  18.67  17.22        0.00         -3.48    -15.71
# 2018-09-28  22.48  25.40  22.15  20.23        0.00         -0.45     -1.99
# 2018-08-31  21.25  24.28  22.60  19.67        0.00          1.60      7.62
# 2018-07-31  20.38  24.63  21.00  19.23        0.00          0.61      2.99
# 2018-06-29  17.21  20.78  20.39  16.46        0.00          3.01     17.32
# 2018-05-31  19.36  20.89  17.38  16.67        0.00         -2.22    -11.33
# 2018-04-27  21.20  21.70  19.60  18.00        0.00         -1.17     -5.63
# 2018-03-30  14.50  20.77  20.77  14.47        0.00          6.09     41.48
# 2018-02-28  14.33  14.93  14.68  12.85        0.00          0.35      2.44
# 2018-01-31  15.44  15.86  14.33  13.70        0.00         -1.11     -7.19
# 2017-12-29  15.50  16.48  15.44  15.08        0.00         -0.07     -0.45
# 2017-11-30  16.50  17.40  15.51  15.45   292981.12         -0.97     -5.89
# 2017-10-31  17.92  18.38  16.48  16.20  1125982.12         -1.26     -7.10
# 2017-09-29  17.75  19.18  17.74  17.00  2110276.75         -0.01     -0.06
# 2017-08-31  16.37  18.53  17.75  15.75  2722936.00          1.40      8.56
# 2017-07-31  16.50  16.97  16.35  15.02  1502287.62          0.00      0.00
#
#                ma5    ma10    ma20       v_ma5      v_ma10      v_ma20
# date
# 2019-02-20  16.922  18.813  17.839   668456.05   334228.03   554837.19
# 2019-01-31  18.112  19.153  17.847   429471.60   214735.80   585401.43
# 2018-12-28  20.030  19.929  17.983        0.00        0.00   613485.39
# 2018-11-30  20.564  19.564  18.032        0.00        0.00   788356.34
# 2018-10-31  20.962  19.157  17.961        0.00        0.00   904525.01
# 2018-09-28  20.704  18.834  17.853        0.00        0.00   967269.74
# 2018-08-31  20.194  18.170  17.553        0.00    29298.11  1040877.20
# 2018-07-31  19.828  17.558  17.293        0.00   141896.32  1147740.17
# 2018-06-29  18.564  17.232  17.215        0.00   352924.00  1220446.14
# 2018-05-31  17.352  16.968  17.191        0.00   625217.60  1270349.36
# 2018-04-27  16.964  16.865  17.322        0.00   775446.36  1344298.81
# 2018-03-30  16.146  16.540  17.408    58596.22   956067.06  1467075.66
# 2018-02-28  15.288  16.037  17.449   283792.65  1226970.79  1697020.28
# 2018-01-31  15.900  16.500  17.940   705848.00  1576712.69  2013495.11
# 2017-12-29  16.584  16.765  18.287  1250435.20  1809050.01  2289131.43
# 2017-11-30  16.766  16.871  19.365  1550892.72  1934539.47  2423469.64
# 2017-10-31  16.934  16.935  20.672  1853537.90  2052456.29  2540842.91
# 2017-09-29  16.786  17.027  21.237  2170148.92  2153584.02  2566976.79
# 2017-08-31  17.100  17.198  21.724  2447577.37  2087968.29  2525417.56
# 2017-07-31  16.946  17.414  22.787  2367664.82  1915481.11  2483301.33

# %%
len(df)
# Out:
# 109

# %%
# 绘制价格曲线图。
def splot(dfx):
    fig=plt.figure(figsize=(48,4), dpi=80)
    p1=fig.add_subplot(1,1,1)

    p1.plot(dfx.index,dfx['open'])
    p1.plot(dfx.index,dfx['close'])
    p1.plot(dfx.index,dfx['high'])
    p1.plot(dfx.index,dfx['low'])
    plt.grid(True)
    plt.gcf().autofmt_xdate()
    plt.show()

# 绘制价格变动率和变动的百分比率。    
def splotbar(dfx):
    fig=plt.figure(figsize=(48,4), dpi=80)
    p1=fig.add_subplot(1,1,1)

    p1.plot(dfx.index,dfx['p_change'], color='red')
    p1.bar(dfx.index,dfx['price_change'])
    plt.grid(True)
    plt.gcf().autofmt_xdate()
    plt.show()

# %%
# 排序
df2=df.sort_index(ascending=True)

# %% [markdown]
# ### 绘制价格曲线图，价格变动与变动率曲线图。

# %%
splot(df2)

# %%
splotbar(df2)

# %% [markdown]
# ### 变动率分析。

# %%
# 获取价格变动及其变动率，构建新的df2v，计算累积求和，并绘制曲线。
df2v = pd.DataFrame(df2,columns=("price_change","p_change")).sort_index(ascending=True)
df2c=df2v.cumsum()

df2c.plot(kind='line',figsize=(32,4),grid=True)
df2c.plot(kind='bar',figsize=(32,4),grid=True)

# %% [markdown]
# # 逐年分析
# 获取周线数据分析绘图，进行逐年比较。

# %%
def getYear(year=2018):
    dfy = ts.get_hist_data('300036', start=str(year)+"-01-01", end=str(year+1)+"-01-01", ktype='W')
    dfy = dfy.sort_index(ascending=True)
    return dfy

def plotYear(year=2018):
    dfy = getYear(year)
    splot(dfy)
    splotbar(dfy)
    return dfy

# %%
dfy2018 = plotYear(2018)

# %%
dfy2017=plotYear(2017)

# %%
dfy2016=plotYear(2016)

# %%
plotYear(2015)

# %%
plotYear(2014)

# %%
plotYear(2013)

# %%
plotYear(2012)

# %%
plotYear(2011)

# %%
plotYear(2010)

# %%
plotYear(2009)
