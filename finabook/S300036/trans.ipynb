# %%
import tushare as ts

# %%
df = ts.get_hist_data('300036',ktype='M')

# %%
df
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2018-07-30  20.38  24.63  21.58  19.23        0.00          1.51      7.41
# 2018-06-29  17.21  20.78  20.39  16.46        0.00          3.01     17.32
# 2018-05-31  19.36  20.89  17.38  16.67        0.00         -2.22    -11.33
# 2018-04-27  21.20  21.70  19.60  18.00        0.00         -1.17     -5.63
# 2018-03-30  14.50  20.77  20.77  14.47        0.00          6.09     41.48
# 2018-02-28  14.33  14.93  14.68  12.85        0.00          0.35      2.44
# 2018-01-31  15.44  15.86  14.33  13.70        0.00         -1.11     -7.19
# 2017-12-29  15.50  16.48  15.44  15.08        0.00         -0.07     -0.45
# 2017-11-30  16.50  17.40  15.51  15.45   292981.12         -0.97     -5.89
# 2017-10-31  17.92  18.38  16.48  16.20  1125982.12         -1.26     -7.10
# 2017-09-29  17.75  19.18  17.74  17.00  2110276.75         -0.01     -0.06
# ...

# %%
import pandas  as pd
import numpy  as np
import matplotlib.pyplot as plt
from   pylab  import  *

# %%
def splot(dfx):
    #创建一个画布对象。一个画布可以有多幅子图。
    fig=plt.figure(figsize=(48,4), dpi=80)

    #在画布中创建一个子图，指定一行、一列的第一幅。
    p1=fig.add_subplot(1,1,1)

    #绘制第一条曲线。
    p1.plot(dfx.index,dfx['open'])
    p1.plot(dfx.index,dfx['close'])
    p1.plot(dfx.index,dfx['high'])
    p1.plot(dfx.index,dfx['low'])

    #显示图形。
    plt.show()

# %%
def splotbar(dfx):
    #创建一个画布对象。一个画布可以有多幅子图。
    fig=plt.figure(figsize=(48,4), dpi=80)

    #在画布中创建一个子图，指定一行、一列的第一幅。
    p1=fig.add_subplot(1,1,1)

    #绘制第一条曲线。
    p1.bar(dfx.index,dfx['p_change'], facecolor='#9999ff', edgecolor='white')
    p1.plot(dfx.index,dfx['p_change'])
    #显示图形。
    plt.show()

# %%
df2=df["2018-08-01":"2016-01-01"]

# %%
df2 = df2.sort_index(ascending=True)

# %%
splot(df2)

# %%
df2018 = ts.get_hist_data('300036',start="2018-01-01",end="2018-08-01",ktype="w")

# %%
df2018 = df2018.sort_index(ascending=True)

# %%
df2018
# Out:
#              open   high  close    low  volume  price_change  p_change  \
# date
# 2018-01-05  15.44  15.86  15.35  15.33     0.0         -0.09     -0.58
# 2018-01-12  15.48  15.65  15.29  15.14     0.0         -0.06     -0.39
# 2018-01-19  15.00  15.00  14.17  13.70     0.0         -1.12     -7.33
# 2018-01-26  14.13  15.68  15.15  13.90     0.0          0.98      6.92
# 2018-02-02  15.25  15.27  14.15  13.72     0.0         -1.00     -6.60
# 2018-02-09  13.76  14.12  13.09  12.85     0.0         -1.06     -7.49
# 2018-02-14  13.30  14.04  13.60  13.18     0.0          0.51      3.90
# 2018-02-23  13.60  14.93  13.89  12.85     0.0          0.29      2.13
# 2018-03-02  13.90  15.87  15.47  13.90     0.0          1.58     11.38
# 2018-03-09  15.60  16.45  16.37  15.26     0.0          0.90      5.82
# 2018-03-16  16.59  16.88  15.53  15.50     0.0         -0.84     -5.13
# 2018-03-23  15.43  16.29  15.14  14.96     0.0         -0.39     -2.51
# ...

# %%
splot(df2018)

# %%
splotbar(df2018)
