# %% [markdown]
# # 股票分类数据
#
# - 来自 http://tushare.org/classifying.html 的股票分类数据。
#
# 分类数据提供股票的分类信息数据，从股票类型的不同角度进行数据分类，在一些统计套利方法的应用中，时常会以股票的分类来做切入，比如对某些行业或概念进行阶段统计来决定近期的交易策略等。TuShare提供的分类数据主要包括以下类别：
#
#     行业分类
#     概念分类
#     地域分类
#     中小板分类
#     创业板分类
#     风险警示板分类
#     沪深300成份股及权重
#     上证50成份股
#     中证500成份股
#     终止上市股票列表
#     暂停上市股票列表
#
# 行业分类
#
# 在现实交易中，经常会按行业统计股票的涨跌幅或资金进出，本接口按照sina财经对沪深股票进行的行业分类，返回所有股票所属行业的信息。考虑到是一次性在线获取数据，调用接口时会有一定的延时，请在数据返回后自行将数据进行及时存储。sina财经提供的行业分类信息大致如下图所示：
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#     c_name：行业名称
#
# 调用方法：
#
# import tushare as ts
#
# ts.get_industry_classified()

# %%
import tushare as ts

ts.get_industry_classified()
# Out:
#         code    name c_name
# 0     600051    宁波联合   综合行业
# 1     600209    罗顿发展   综合行业
# 2     600212    江泉实业   综合行业
# 3     600256    广汇能源   综合行业
# 4     600576    祥源文化   综合行业
# 5     600603    广汇物流   综合行业
# 6     600614    鹏起科技   综合行业
# 7     600620    天宸股份   综合行业
# 8     600622    光大嘉宝   综合行业
# 9     600624    复旦复华   综合行业
# 10    600647    同达创业   综合行业
# 11    600656    退市博元   综合行业
# 12    600687    刚泰控股   综合行业
# 13    600701    工大高新   综合行业
# 14    600730    中国高科   综合行业
# 15    600770    综艺股份   综合行业
# 16    600777    新潮能源   综合行业
# 17    600800    天津磁卡   综合行业
# 18    600805    悦达投资   综合行业
# 19    600811    东方集团   综合行业
# 20    600832    东方明珠   综合行业
# 21    600846    同济科技   综合行业
# 22    600892    大晟文化   综合行业
# 23    000008    神州高铁   综合行业
# 24    000301    东方市场   综合行业
# 25    000576    广东甘化   综合行业
# 26    000632    三木集团   综合行业
# 27    000633    合金投资   综合行业
# 28    000652    泰达股份   综合行业
# 29    000701    厦门信达   综合行业
# ...      ...     ...    ...
# 2878  600983     惠而浦   家电行业
# 2879  603366    日出东方   家电行业
# 2880  603519    立霸股份   家电行业
# 2881  000016    深康佳Ａ   家电行业
# 2882  000100  TCL 集团   家电行业
# 2883  000333    美的集团   家电行业
# 2884  000418    小天鹅Ａ   家电行业
# 2885  000521    美菱电器   家电行业
# 2886  000527    美的电器   家电行业
# 2887  000533   万 家 乐   家电行业
# 2888  000541    佛山照明   家电行业
# 2889  000651    格力电器   家电行业
# 2890  000921    海信科龙   家电行业
# 2891  002005    德豪润达   家电行业
# 2892  002032   苏 泊 尔   家电行业
# 2893  002035    华帝股份   家电行业
# 2894  002076   雪 莱 特   家电行业
# 2895  002242    九阳股份   家电行业
# 2896  002260    德奥通航   家电行业
# 2897  002290    中科新材   家电行业
# 2898  002403     爱仕达   家电行业
# 2899  002429    兆驰股份   家电行业
# 2900  002473   *ST圣莱   家电行业
# 2901  002508    老板电器   家电行业
# 2902  002543    万和电气   家电行业
# 2903  002668    奥马电器   家电行业
# 2904  002677    浙江美大   家电行业
# 2905  002681    奋达科技   家电行业
# 2906  002705    新宝股份   家电行业
# 2907  002723     金莱特   家电行业
#
# [2908 rows x 3 columns]

# %% [markdown]
# # 概念分类
#
# 返回股票概念的分类数据，现实的二级市场交易中，经常会以”概念”来炒作，在数据分析过程中，可根据概念分类监测资金等信息的变动情况。本接口是一次性在线获取数据，调用接口时会有一定的延时，请在数据返回后自行将数据进行及时存储。sina财经提供的概念分类信息大致如下图所示：
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#     c_name：概念名称
#
# 调用方法：
#
# import tushare as ts
#
# ts.get_concept_classified()

# %% [markdown]
# # 地域分类
#
# 按地域对股票进行分类，即查找出哪些股票属于哪个省份。
#
# 参数说明：
#
#     file_path:文件路径，默认为None即由TuShare提供，可以设定自己的股票文件路径。
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#     area：地域名称
#
# 调用方法：
#
# import tushare as ts
#
# ts.get_area_classified()

# %%
import tushare as ts

ts.get_area_classified()
# Out:
#         code   name area
# 0     300153   科泰电源   上海
# 1     300398   飞凯材料   上海
# 2     300253   卫宁健康   上海
# 3     603131   上海沪工   上海
# 4     600503   华丽家族   上海
# 5     601021   春秋航空   上海
# 6     600021   上海电力   上海
# 7     300590   移为通信   上海
# 8     600615   丰华股份   上海
# 9     603683   晶华新材   上海
# 10    600613   神奇制药   上海
# 11    600097   开创国际   上海
# 12    600171   上海贝岭   上海
# 13    603918   金桥信息   上海
# 14    300067    安诺其   上海
# 15    603232   格尔软件   上海
# 16    300272   开能健康   上海
# 17    603083   剑桥科技   上海
# 18    601607   上海医药   上海
# 19    002561    徐家汇   上海
# 20    600630   龙头股份   上海
# 21    300262   巴安水务   上海
# 22    603729   龙韵股份   上海
# 23    601211   国泰君安   上海
# 24    300126   锐奇股份   上海
# 25    600708   光明地产   上海
# 26    601968   宝钢包装   上海
# 27    600675   中华企业   上海
# 28    002565   顺灏股份   上海
# 29    603855   华荣股份   上海
# ...      ...    ...  ...
# 3508  600356   恒丰纸业  黑龙江
# 3509  603567    珍宝岛  黑龙江
# 3510  600179   安通控股  黑龙江
# 3511  002737   葵花药业  黑龙江
# 3512  600371   万向德农  黑龙江
# 3513  600705   中航资本  黑龙江
# 3514  600664   哈药股份  黑龙江
# 3515  603023   威帝股份  黑龙江
# 3516  600829   人民同泰  黑龙江
# 3517  600701  *ST工新  黑龙江
# 3518  300040   九洲电气  黑龙江
# 3519  600598    北大荒  黑龙江
# 3520  300489   中飞股份  黑龙江
# 3521  600038   中直股份  黑龙江
# 3522  002698   博实股份  黑龙江
# 3523  600178   东安动力  黑龙江
# 3524  600187   国中水务  黑龙江
# 3525  600811   东方集团  黑龙江
# 3526  601011    宝泰隆  黑龙江
# 3527  600182    S佳通  黑龙江
# 3528  000587   金洲慈航  黑龙江
# 3529  600853   龙建股份  黑龙江
# 3530  000711   京蓝科技  黑龙江
# 3531  002437   誉衡药业  黑龙江
# 3532  600289  *ST信通  黑龙江
# 3533  600891   秋林集团  黑龙江
# 3534  600864   哈投股份  黑龙江
# 3535  600095    哈高科  黑龙江
# 3536  000985   大庆华科  黑龙江
# 3537  601106   中国一重  黑龙江
#
# [3538 rows x 3 columns]

# %% [markdown]
# # 中小板分类
#
# 获取中小板股票数据，即查找所有002开头的股票
#
# 参数说明：
#
#     file_path:文件路径，默认为None即由TuShare提供，可以设定自己的股票文件路径。
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#
# 调用方法：
#
# import tushare as ts
#
# ts.get_sme_classified()

# %% [markdown]
# # 创业板分类
#
# 获取创业板股票数据，即查找所有300开头的股票
#
# 参数说明：
#
#     file_path:文件路径，默认为None即由TuShare提供，可以设定自己的股票文件路径。
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#
# 调用方法：
#
# import tushare as ts
#
# ts.get_gem_classified()

# %%
import tushare as ts

ts.get_gem_classified()
# Out:
#        code  name
# 0    300001   特锐德
# 1    300002  神州泰岳
# 2    300003  乐普医疗
# 3    300004  南风股份
# 4    300005   探路者
# 5    300006  莱美药业
# 6    300007  汉威科技
# 7    300008  天海防务
# 8    300009  安科生物
# 9    300010   立思辰
# 10   300011  鼎汉技术
# 11   300012  华测检测
# 12   300013  新宁物流
# 13   300014  亿纬锂能
# 14   300015  爱尔眼科
# 15   300016  北陆药业
# 16   300017  网宿科技
# 17   300018  中元股份
# 18   300019  硅宝科技
# 19   300020  银江股份
# 20   300021  大禹节水
# 21   300022  吉峰农机
# 22   300023  宝德股份
# 23   300024   机器人
# 24   300025  华星创业
# 25   300026  红日药业
# 26   300027  华谊兄弟
# 27   300028   *金亚
# 28   300029  天龙光电
# 29   300030  阳普医疗
# ..      ...   ...
# 700  300716  国立科技
# 701  300717  华信新材
# 702  300718  长盛轴承
# 703  300719  安达维尔
# 704  300720  海川智能
# 705  300721  怡达股份
# 706  300722  新余国科
# 707  300723   一品红
# 708  300724  捷佳伟创
# 709  300725  药石科技
# 710  300726  宏达电子
# 711  300727  润禾材料
# 712  300729  乐歌股份
# 713  300730  科创信息
# 714  300731  科创新源
# 715  300732   设研院
# 716  300733  西菱动力
# 717  300735  光弘科技
# 718  300736  百华悦邦
# 719  300737  科顺股份
# 720  300738  奥飞数据
# 721  300739  明阳电路
# 722  300740   御家汇
# 723  300741  华宝股份
# 724  300742  越博动力
# 725  300743  天地数码
# 726  300745  欣锐科技
# 727  300746  汉嘉设计
# 728  300747  锐科激光
# 729  300750  宁德时代
#
# [730 rows x 2 columns]

# %% [markdown]
# # 风险警示板分类
#
# 获取风险警示板股票数据，即查找所有st股票
#
# 参数说明：
#
#     file_path:文件路径，默认为None即由TuShare提供，可以设定自己的股票文件路径。
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#
# 调用方法：
#
# import tushare as ts
#
# ts.get_st_classified()

# %% [markdown]
# # 沪深300成份及权重
#
# 获取沪深300当前成份股及所占权重
#
# 返回值说明：
#
#     code :股票代码
#     name :股票名称
#     date :日期
#     weight:权重
#
# 调用方法：
# ```
# import tushare as ts
# ts.get_hs300s()
# ```

# %% [markdown]
# # 上证50成份股
#
# 获取上证50成份股
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#
# 调用方法：
# ```
# import tushare as ts
# ts.get_sz50s()
# ```

# %% [markdown]
# # 中证500成份股
#
# 获取中证500成份股
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#
# 调用方法：
# ```
# import tushare as ts
# ts.get_zz500s()
# ```

# %% [markdown]
# # 终止上市股票列表
#
# 获取已经被终止上市的股票列表，数据从上交所获取，目前只有在上海证券交易所交易被终止的股票。
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#     oDate:上市日期
#     tDate:终止上市日期
#
# 调用方法：
# ```
# import tushare as ts
# ts.get_terminated()
# ```

# %%
import tushare as ts
ts.get_terminated()
# Out:
# HTTP Error 403: Forbidden

# %% [markdown]
# # 暂停上市股票列表
#
# 获取被暂停上市的股票列表，数据从上交所获取，目前只有在上海证券交易所交易被终止的股票。
#
# 返回值说明：
#
#     code：股票代码
#     name：股票名称
#     oDate:上市日期
#     tDate:暂停上市日期
#
# 调用方法：
# ```
# import tushare as ts
# ts.get_suspended()
# ```

# %%
import tushare as ts
ts.get_suspended()
# Out:
# HTTP Error 403: Forbidden
