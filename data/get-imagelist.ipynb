# %%
# coding:utf-8
# 引入requests包和正则表达式包re
import requests
import re
import pprint
from bs4 import BeautifulSoup

# %%
def load_page(url):
    response=requests.get(url)
    data=response.content
    return data

# %%
def get_list(url_region):
    # 定义爬取页面的链接
    # 调用load_page函数，下载页面内容
    html = load_page(url_region)
    #pprint.pprint(html)
    
    regx=r'_src="https://pan[\S]*"'  # 定义图片正则表达式
    pattern=re.compile(regx) # 编译表达式构造匹配模式
    get_images=re.findall(pattern,repr(html)) # 在页面中匹配图片链接
    
    print("发现图像,共计：",len(get_images))
    return get_images

# %%
def save_list(k,image_list):
    with open("list.txt","a") as flist:
        flist.writelines("#",k,"\n")
        for aurl in get_images:
            aurl = aurl[6:53] + "\n"
            pprint.pprint(str(aurl))
            flist.writelines(aurl)

# %%
# Read region list from file to dict. 
with open("list.txt", "w") as flist:
    flist.writelines("#list file for SJZ images.\n")

# For each region, get image list.
with open('region.txt', 'r') as fregion:
    region_list = eval(fregion.read())
    # print(region_list,"\n")
    
    for k in region_list:
        print("Get image list of region: ", k,",",region_list[k])
        image_list = get_list(region_list[k])
        save_list(k,image_list)
        print("ok.\n")
# Out:
# Get image list of region:  2109-浙江省卫星地图离线包下载 , http://www.rivermap.cn/help/show-2109.html
# ok.
#
# Get image list of region:  2108-云南省卫星地图离线包下载 , http://www.rivermap.cn/help/show-2108.html
# ok.
#
# Get image list of region:  2107-新疆卫星地图离线包下载 , http://www.rivermap.cn/help/show-2107.html
# ok.
#
# Get image list of region:  2099-四川省卫星地图离线包下载 , http://www.rivermap.cn/help/show-2099.html
# ok.
#
# Get image list of region:  2097-天津市卫星地图离线包下载 , http://www.rivermap.cn/help/show-2097.html
# ok.
#
# Get image list of region:  2095-台湾省卫星地图离线包下载 , http://www.rivermap.cn/help/show-2095.html
# ok.
#
# Get image list of region:  2093-香港卫星地图离线包下载 , http://www.rivermap.cn/help/show-2093.html
# ok.
#
# Get image list of region:  2091-澳门卫星地图离线包下载 , http://www.rivermap.cn/help/show-2091.html
# ok.
#
# Get image list of region:  2089-上海市卫星地图离线包下载 , http://www.rivermap.cn/help/show-2089.html
# ok.
#
# Get image list of region:  2087-广东省卫星地图离线包下载 , http://www.rivermap.cn/help/show-2087.html
# ok.
#
# Get image list of region:  2086-辽宁省卫星地图离线包下载 , http://www.rivermap.cn/help/show-2086.html
# ok.
#
# Get image list of region:  2085-西藏自治区卫星地图离线包下载 , http://www.rivermap.cn/help/show-2085.html
